# %%
import pandas as pd

# %%
df = pd.read_csv("Excel3.csv")

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df.sort_values("Year")
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
#
#     Boxoffice(INR Crore)   IMDp
# 2                    2024   8.4
# 1                     760   6.0
# ...

# %%
df.sort_values("Year", ascending=False)
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 8        Akashy kumar           Good News  2019           Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 2          Aamir khan              Dangal  2016        Biography
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 3                     431   5.6
# ...

# %%
df.sort_values("IMDp")
# Out:
#                 Actor                Film  Year            Genre  \
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 7    Hritithik Roshan                 War  2018          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 8        Akashy kumar           Good News  2019           Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 2          Aamir khan              Dangal  2016        Biography
#
#     Boxoffice(INR Crore)   IMDp
# 3                     431   5.6
# 9                     266   5.8
# ...

# %%
df.sort_values("IMDp", ascending=False)
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 11      Vicky kaushal                 Uri  2019          Action
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 8        Akashy kumar           Good News  2019           Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
#
#     Boxoffice(INR Crore)   IMDp
# 2                    2024   8.4
# 5                     111   8.3
# ...

# %%
df2 = df.sort_values(["Year", "IMDp"]).copy()

# %%
df2.reset_index()
# Out:
#     index              Actor                Film  Year            Genre  \
# 0       2         Aamir khan              Dangal  2016        Biography
# 1       1        Salman khan    Tiger Zinda hai   2017          Action
# 2      10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 3       7   Hritithik Roshan                 War  2018          Action
# 4       4      Ranveer singh           Padmaavat  2018       Historical
# 5       6       Rajkumar Rao               Stree  2018    Horror Comedy
# 6       5  Ayushmann khurann           Andhadhan  2018         Thriller
# 7       8       Akashy kumar           Good News  2019           Comedy
# 8      11      Vicky kaushal                 Uri  2019          Action
# 9       3      Ranbir kapoor         Brahmasatre  2022          Fantacy
# 10      9       Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 11      0     Shah Rukh khan              Pathan  2023          Action
#
#     Boxoffice(INR Crore)   IMDp
# ...

# %%
# df2.reset_index(drop=True)

# %%
df2 #no change of the old data frame
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 7    Hritithik Roshan                 War  2018          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 8        Akashy kumar           Good News  2019           Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
#
#     Boxoffice(INR Crore)   IMDp
# 2                    2024   8.4
# 1                     760   6.0
# ...

# %%
# df2.reset_index(drop= True, inplace=True) #no need to run .copy() funtion

# %% [markdown]
# # SORTING IN INDEX

# %%
df2
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 7    Hritithik Roshan                 War  2018          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 8        Akashy kumar           Good News  2019           Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
#
#     Boxoffice(INR Crore)   IMDp
# 2                    2024   8.4
# 1                     760   6.0
# ...

# %%
df2.sort_index()
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df2["Rank"] = df2["IMDp"].rank(ascending = False, method= "dense")

# %%
df2.sort_values("Rank")
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 11      Vicky kaushal                 Uri  2019          Action
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 8        Akashy kumar           Good News  2019           Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
#
#     Boxoffice(INR Crore)   IMDp  Rank
# 2                    2024   8.4   1.0
# 5                     111   8.3   2.0
# ...

# %%
df2
# Out:
#                 Actor                Film  Year            Genre  \
# 2          Aamir khan              Dangal  2016        Biography
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 7    Hritithik Roshan                 War  2018          Action
# 4       Ranveer singh           Padmaavat  2018       Historical
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 8        Akashy kumar           Good News  2019           Comedy
# 11      Vicky kaushal                 Uri  2019          Action
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 0      Shah Rukh khan              Pathan  2023          Action
#
#     Boxoffice(INR Crore)   IMDp  Rank
# 2                    2024   8.4   1.0
# 1                     760   6.0  10.0
# ...

# %%
df2.rename(columns = {"Actor" : "Superster"}, inplace = True)

# %%
df2
# Out:
#                      Rank               Genre  Film             Year  IMDp  \
# 2              Aamir khan              Dangal  2016        Biography  2024
# salman        Salman khan    Tiger Zinda hai   2017          Action    760
# 10          Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy   201
# 7        Hritithik Roshan                 War  2018          Action    475
# 4           Ranveer singh           Padmaavat  2018       Historical   585
# 6            Rajkumar Rao               Stree  2018    Horror Comedy   180
# 5       Ayushmann khurann           Andhadhan  2018         Thriller   111
# 8            Akashy kumar           Good News  2019           Comedy   318
# 11          Vicky kaushal                 Uri  2019          Action    343
# 3           Ranbir kapoor         Brahmasatre  2022          Fantacy   431
# 9            Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy   266
# ...

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df = df[["Year", "Actor", "Film", "Genre", "IMDp","Boxoffice(INR Crore)"]]
