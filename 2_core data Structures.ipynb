# %%
import pandas as pd

# %%
s1 = pd.Series([78, 98, 67, 78, 87, 87, 95])

# %%
print(s1)
# Out:
# 0    78
# 1    98
# 2    67
# 3    78
# 4    87
# 5    87
# 6    95
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([78, 98, 67, 78, 87, 87, 95], index=["SONU", "MONI", "RADHA", "VIRAT", "SHAAM", "VIJAY", "MANISH"])

# %%
s2
# Out:
# SONU      78
# MONI      98
# RADHA     67
# VIRAT     78
# SHAAM     87
# VIJAY     87
# MANISH    95
# dtype: int64

# %%
s2["SONU"]
# Out:
# np.int64(78)

# %%
S3 = pd.Series([ 99, 98, 97, 96, 95, 94, 98], index =['Rohit', 'Moni', 'Vikas', 'John', 'Harry', 'Dirko', 'Sonu'] )

# %%
S3
# Out:
# Rohit    99
# Moni     98
# Vikas    97
# John     96
# Harry    95
# Dirko    94
# Sonu     98
# dtype: int64

# %%
type(S3)
# Out:
# pandas.core.series.Series

# %%
# Data fram = 2D labeled table
data = {
    'Name' : ['sonu', 'monu', 'shivani', 'radha'],
    'Age' : [35, 23, 54, 32],
    'City' : ['Delhi', 'Mumbai', 'Rajisthan', 'Uttar pardash'],
    'Region' : ['Indian', 'Indian', 'Indian','Indian']
    
}

# %%
pd.DataFrame(data)
# Out:
#       Name  Age           City  Region
# 0     sonu   35          Delhi  Indian
# 1     monu   23         Mumbai  Indian
# 2  shivani   54      Rajisthan  Indian
# 3    radha   32  Uttar pardash  Indian

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age           City  Region
# 0     sonu   35          Delhi  Indian
# 1     monu   23         Mumbai  Indian
# 2  shivani   54      Rajisthan  Indian
# 3    radha   32  Uttar pardash  Indian

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Region'], dtype='object')
