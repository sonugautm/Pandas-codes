# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False  False  False   False  False      False
# 4   True  False  False   False  False       True

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          1
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com    1/5/2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df.fillna('-')
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie     -        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4        -  28.0        Delhi      F     eve@domain.com           -

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.00
# 1    26.25
# 2    30.00
# 3    22.00
# 4    28.00
# Name: Age, dtype: float64

# %%
df.fillna(method = "ffill")
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_6264\1983593268.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4    David  28.0        Delhi      F     eve@domain.com  12/11/2019

# %%
df.fillna(method= "bfill")
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_6264\3528466224.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method= "bfill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4    David  28.0        Delhi      F     eve@domain.com  12/11/2019

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 7      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8    David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset = ["Name", "City"])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 7      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8    David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df['Name'].str.lower() #its convert of the letter into small litter
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3      david
# 4        NaN
# 5        bob
# 6      david
# 7        bob
# 8      david
# Name: Name, dtype: object

# %%
df["Name"].str.upper() #all the name letter convert into upper form
# Out:
# 0      ALICE
# 1    CHARLIE
# 2        BOB
# 3      DAVID
# 4        NaN
# 5        BOB
# 6      DAVID
# 7        BOB
# 8      DAVID
# Name: Name, dtype: object

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 7      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8    David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df["City"].str.contains("Delhi", case=False) #checking the if delhi is in city name in case = True/False
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# Name: City, dtype: bool

# %%
type(df["City"].str.contains("Delhi", case=False))
# Out:
# pandas.core.series.Series

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3    [david, example.com]
# 4       [eve, domain.com]
# 5      [bob, example.com]
# 6    [david, example.com]
# 7      [bob, example.com]
# 8    [david, example.com]
# Name: Email, dtype: object

# %%
type(df["Email"].str.split("@")[0])
# Out:
# list

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 7      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8    David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df2 = df.dropna().copy()

# %%
df2['Age'] = df2['Age'].astype(int)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  David   22       Mumbai      M  david@example.com  12/11/2019
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 6  David   22       Mumbai      M  david@example.com  12/11/2019
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 8  David   22       Mumbai      M  david@example.com  12/11/2019

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  David   22       Mumbai      M  david@example.com  12/11/2019
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 6  David   22       Mumbai      M  david@example.com  12/11/2019
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 8  David   22       Mumbai      M  david@example.com  12/11/2019

# %%
df2.drop_duplicates()
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  David   22       Mumbai      M  david@example.com  12/11/2019

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  David   22       Mumbai      M  david@example.com  12/11/2019
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 6  David   22       Mumbai      M  david@example.com  12/11/2019
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 8  David   22       Mumbai      M  david@example.com  12/11/2019

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       7 non-null      object
#  1   Age        7 non-null      int64
#  2   City       7 non-null      object
#  3   Gender     7 non-null      object
#  4   Email      7 non-null      object
#  5   Join Date  7 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 392.0+ bytes

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date
# 0  Alice   25     New York      F  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  David   22       Mumbai      M  david@example.com  12/11/2019
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 6  David   22       Mumbai      M  david@example.com  12/11/2019
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 8  David   22       Mumbai      M  david@example.com  12/11/2019

# %%
df2['Age Group'] = df2['Age'].apply(lambda x: 'Adult' if x >= 25 else 'Minor')

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com    1/5/2021     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 3  David   22       Mumbai      M  david@example.com  12/11/2019     Minor
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 6  David   22       Mumbai      M  david@example.com  12/11/2019     Minor
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 8  David   22       Mumbai      M  david@example.com  12/11/2019     Minor

# %%
def isminor(x):
    return "Audlt" if x >= 25 else "Minor"

df2['Age Group'] = df2['Age'].apply(isminor)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com    1/5/2021     Audlt
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Audlt
# 3  David   22       Mumbai      M  david@example.com  12/11/2019     Minor
# 5    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Audlt
# 6  David   22       Mumbai      M  david@example.com  12/11/2019     Minor
# 7    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Audlt
# 8  David   22       Mumbai      M  david@example.com  12/11/2019     Minor

# %%
gender_map = {"M": "Male", "F": "Female", "O": "Other"}
df2["Gender"] = df2["gender"].map(gender_map)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York    NaN  alice@example.com    1/5/2021     Audlt
# 2    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Audlt
# 3  David   22       Mumbai    NaN  david@example.com  12/11/2019     Minor
# 5    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Audlt
# 6  David   22       Mumbai    NaN  david@example.com  12/11/2019     Minor
# 7    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Audlt
# 8  David   22       Mumbai    NaN  david@example.com  12/11/2019     Minor

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 7      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 8    David  22.0       Mumbai      M  david@example.com  12/11/2019

# %%
df = df["City"].replace({"Mumbai": "New Delhi"})

# %%
df
# Out:
# 0       New York
# 1          Delhi
# 2    Los Angeles
# 3      New Delhi
# 4          Delhi
# 5    Los Angeles
# 6      New Delhi
# 7    Los Angeles
# 8      New Delhi
# Name: City, dtype: object

# %%
df
# Out:
# 0       New York
# 1          Delhi
# 2    Los Angeles
# 3      New Delhi
# 4          Delhi
# 5    Los Angeles
# 6      New Delhi
# 7    Los Angeles
# 8      New Delhi
# Name: City, dtype: object
