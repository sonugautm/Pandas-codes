# %%
import pandas as pd

# %%
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
pd.merge(employees, departments, on="DeptID")#inner join
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %%
pd.merge(employees, departments, on="DeptID", how="left")#left join
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %%
pd.merge(employees, departments, on="DeptID", how= "right")#right join
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
pd.merge(employees, departments, on="DeptID", how= "outer")#outer join
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"], "Score": [908, 980]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"], "Age": [34, 22]})

pd.concat([df1, df2])
# Out:
#       Name  Score   Age
# 0    Alice  908.0   NaN
# 1      Bob  980.0   NaN
# 0  Charlie    NaN  34.0
# 1    David    NaN  22.0

# %%
df1
# Out:
#     Name
# 0  Alice
# 1    Bob

# %%
df2
# Out:
#       Name
# 0  Charlie
# 1    David

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     Name  Score     Name  Age
# 0  Alice    908  Charlie   34
# 1    Bob    980    David   22

# %%
df1 = pd.DataFrame({"Name": ["Sonu", "Raj", "Kumar"],"Roll no":[88, 90, 95]})
df2 = pd.DataFrame({"Name": ["Rahul", "Radha"], "Age":[56, 45]})

# %%
df1
# Out:
#     Name  Score
# 0  Alice    908
# 1    Bob    980

# %%
df2
# Out:
#     Name  Age
# 0  Rahul   56
# 1  Radha   45

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     Name  Roll no   Name   Age
# 0   Sonu       88  Rahul  56.0
# 1    Raj       90  Radha  45.0
# 2  Kumar       95    NaN   NaN

# %%
pd.concat([df1, df2])
# Out:
#     Name  Roll no   Age
# 0   Sonu     88.0   NaN
# 1    Raj     90.0   NaN
# 2  Kumar     95.0   NaN
# 0  Rahul      NaN  56.0
# 1  Radha      NaN  45.0
