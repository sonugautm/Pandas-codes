# %%
import pandas as pd

# %%
df = pd.read_excel("Excel2.xlsx")

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df['Actor']
# Out:
# 0        Shah Rukh khan
# 1           Salman khan
# 2            Aamir khan
# 3         Ranbir kapoor
# 4         Ranveer singh
# 5     Ayushmann khurann
# 6          Rajkumar Rao
# 7      Hritithik Roshan
# 8          Akashy kumar
# 9          Kartik Aryan
# 10        Varun Dhawaan
# 11        Vicky kaushal
# Name: Actor, dtype: object

# %%
df['Actor'][7]
# Out:
# 'Hritithik Roshan'

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
df[['Actor', 'IMDp']]
# Out:
#                 Actor  IMDp
# 0      Shah Rukh khan   7.2
# 1         Salman khan   6.0
# 2          Aamir khan   8.4
# 3       Ranbir kapoor   5.6
# 4       Ranveer singh   7.0
# 5   Ayushmann khurann   8.3
# 6        Rajkumar Rao   7.5
# 7    Hritithik Roshan   6.5
# 8        Akashy kumar   7.0
# 9        Kartik Aryan   5.8
# 10      Varun Dhawaan   6.1
# 11      Vicky kaushal   8.2

# %%
df.loc[0]
# Out:
# Actor                    Shah Rukh khan
# Film                             Pathan
# Year                               2023
# Genre                           Action
# Boxoffice(INR Crore)               1050
# IMDp                                7.2
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Actor                         Salman khan
# Film                     Tiger Zinda hai
# Year                                 2017
# Genre                             Action
# Boxoffice(INR Crore)                  760
# IMDp                                  6.0
# Name: 1, dtype: object

# %%
df.loc[8, 'Film']
# Out:
# 'Good News'

# %%
df.iloc[8, 1]
# Out:
# 'Good News'

# %%
df.loc[0:5, ["Actor", "Film", "Year"]]
# Out:
#                Actor              Film  Year
# 0     Shah Rukh khan            Pathan  2023
# 1        Salman khan  Tiger Zinda hai   2017
# 2         Aamir khan            Dangal  2016
# 3      Ranbir kapoor       Brahmasatre  2022
# 4      Ranveer singh         Padmaavat  2018
# 5  Ayushmann khurann         Andhadhan  2018

# %%
df.iloc[0:5, 0:5]
# Out:
#             Actor              Film  Year       Genre  Boxoffice(INR Crore)
# 0  Shah Rukh khan            Pathan  2023     Action                    1050
# 1     Salman khan  Tiger Zinda hai   2017     Action                     760
# 2      Aamir khan            Dangal  2016   Biography                   2024
# 3   Ranbir kapoor       Brahmasatre  2022     Fantacy                    431
# 4   Ranveer singh         Padmaavat  2018  Historical                    585

# %%
df.at[0, 'Actor']
# Out:
# 'Shah Rukh khan'

# %%
df.iat[0, 3]
# Out:
# 'Action '

# %%
df[df['IMDp']>7]
# Out:
#                 Actor       Film  Year          Genre  Boxoffice(INR Crore)   \
# 0      Shah Rukh khan     Pathan  2023        Action                    1050
# 2          Aamir khan     Dangal  2016      Biography                   2024
# 5   Ayushmann khurann  Andhadhan  2018       Thriller                    111
# 6        Rajkumar Rao      Stree  2018  Horror Comedy                    180
# 11      Vicky kaushal        Uri  2019        Action                     343
#
#     IMDp
# 0    7.2
# 2    8.4
# 5    8.3
# 6    7.5
# 11   8.2

# %%
df[df['IMDp']>7]['Film']
# Out:
# 0        Pathan
# 2        Dangal
# 5     Andhadhan
# 6         Stree
# 11          Uri
# Name: Film, dtype: object

# %%
df[(df['IMDp']>6) & (df['Year']>=2018)]
# Out:
#                 Actor       Film  Year          Genre  Boxoffice(INR Crore)   \
# 0      Shah Rukh khan     Pathan  2023        Action                    1050
# 4       Ranveer singh  Padmaavat  2018     Historical                    585
# 5   Ayushmann khurann  Andhadhan  2018       Thriller                    111
# 6        Rajkumar Rao      Stree  2018  Horror Comedy                    180
# 7    Hritithik Roshan        War  2018        Action                     475
# 8        Akashy kumar  Good News  2019         Comedy                    318
# 11      Vicky kaushal        Uri  2019        Action                     343
#
#     IMDp
# 0    7.2
# 4    7.0
# 5    8.3
# 6    7.5
# 7    6.5
# 8    7.0
# 11   8.2

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df.query("Year > 2019 and IMDp >7")
# Out:
#             Actor    Film  Year    Genre  Boxoffice(INR Crore)   IMDp
# 0  Shah Rukh khan  Pathan  2023  Action                    1050   7.2

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df2 = df[['Actor', 'IMDp']]

# %%
df2
# Out:
#                 Actor  IMDp
# 0      Shah Rukh khan   7.2
# 1         Salman khan   6.0
# 2          Aamir khan   8.4
# 3       Ranbir kapoor   5.6
# 4       Ranveer singh   7.0
# 5   Ayushmann khurann   8.3
# 6        Rajkumar Rao   7.5
# 7    Hritithik Roshan   6.5
# 8        Akashy kumar   7.0
# 9        Kartik Aryan   5.8
# 10      Varun Dhawaan   6.1
# 11      Vicky kaushal   8.2

# %%
df2.loc[0, 'Actor'] = 'Rohit Sharama' #change the name of the list condit.

# %%
df2
# Out:
#                 Actor  IMDp
# 0       Rohit Sharama   7.2
# 1         Salman khan   6.0
# 2          Aamir khan   8.4
# 3       Ranbir kapoor   5.6
# 4       Ranveer singh   7.0
# 5   Ayushmann khurann   8.3
# 6        Rajkumar Rao   7.5
# 7    Hritithik Roshan   6.5
# 8        Akashy kumar   7.0
# 9        Kartik Aryan   5.8
# 10      Varun Dhawaan   6.1
# 11      Vicky kaushal   8.2

# %%
df2
# Out:
#                 Actor  IMDp
# 0       Rohit Sharama   7.2
# 1         Salman khan   6.0
# 2          Aamir khan   8.4
# 3       Ranbir kapoor   5.6
# 4       Ranveer singh   7.0
# 5   Ayushmann khurann   8.3
# 6        Rajkumar Rao   7.5
# 7    Hritithik Roshan   6.5
# 8        Akashy kumar   7.0
# 9        Kartik Aryan   5.8
# 10      Varun Dhawaan   6.1
# 11      Vicky kaushal   8.2

# %%
df
# Out:
#                 Actor                Film  Year            Genre  \
# 0      Shah Rukh khan              Pathan  2023          Action
# 1         Salman khan    Tiger Zinda hai   2017          Action
# 2          Aamir khan              Dangal  2016        Biography
# 3       Ranbir kapoor         Brahmasatre  2022          Fantacy
# 4       Ranveer singh           Padmaavat  2018       Historical
# 5   Ayushmann khurann           Andhadhan  2018         Thriller
# 6        Rajkumar Rao               Stree  2018    Horror Comedy
# 7    Hritithik Roshan                 War  2018          Action
# 8        Akashy kumar           Good News  2019           Comedy
# 9        Kartik Aryan      Bhool bhulaiya  2022    Horror Comedy
# 10      Varun Dhawaan  Badri ki dhulaniya  2017  Romantic comedy
# 11      Vicky kaushal                 Uri  2019          Action
#
#     Boxoffice(INR Crore)   IMDp
# 0                    1050   7.2
# 1                     760   6.0
# ...

# %%
df.at[6, "Film"]
# Out:
# 'Stree'
